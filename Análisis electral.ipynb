# %%
graph LR
    A[Nodo de Decisión] --> B{Lanzar Nacional}
    A --> C{Lanzar Regional}
    A --> D{No Lanzar}

    B -- "Aceptación Alta (0.30)" --> B1[+120 MUSD]
    B -- "Aceptación Mod. (0.50)" --> B2[+40 MUSD]
    B -- "Rechazo (0.20)" --> B3[-60 MUSD]

    C -- "Aceptación Alta (0.30)" --> C1[+30 MUSD]
    C -- "Aceptación Mod. (0.50)" --> C2[+15 MUSD]
    C -- "Rechazo (0.20)" --> C3[-5 MUSD]

    D --> D1[0 MUSD]

    style A fill:#f9f,stroke:#333,stroke-width:2px
    style B fill:#fff,stroke:#333,stroke-width:2px
    style C fill:#fff,stroke:#333,stroke-width:2px
    style D fill:#fff,stroke:#333,stroke-width:2px
